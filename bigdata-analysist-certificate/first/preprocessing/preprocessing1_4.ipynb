# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/bigdata-analysist-certificate/blob/master/bigdata-analysist-certificate/preprocessing/preprocessing1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

DataUrl = 'https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv'
df = pd.read_csv(DataUrl)
ans = type(df)

# %%
df_raw = df[['quantity', 'item_price']]
df_raw['new_price'] = df_raw['item_price'].str[1:].astype('float')
# Out:
# <ipython-input-5-346f1b50d483>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_raw['new_price'] = df_raw['item_price'].str[1:].astype('float')

# %% [markdown]
# ### Question 31. df의 new_price 컬럼 값에 따라 내림차순으로 정리하고 index를 초기화 하여라

# %%
df_raw.sort_values(by='new_price', ascending=False).reset_index().drop('index', axis=1)
# Out:
#       quantity item_price  new_price
# 0           15    $44.25       44.25
# 1            3    $35.25       35.25
# 2            4    $35.00       35.00
# 3            4    $35.00       35.00
# 4            3    $33.75       33.75
# ...        ...        ...        ...
# 4617         1     $1.09        1.09
# 4618         1     $1.09        1.09
# 4619         1     $1.09        1.09
# 4620         1     $1.09        1.09
# 4621         1     $1.09        1.09
#
# [4622 rows x 3 columns]

# %% [markdown]
# ### 32. df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 인덱싱하라

# %%
df[(df['item_name']=='Steak Salad') | (df['item_name'] == 'Bowl')]
# Out:
#       order_id  quantity    item_name  \
# 445        193         3         Bowl
# 664        276         1  Steak Salad
# 673        279         1         Bowl
# 752        311         1  Steak Salad
# 893        369         1  Steak Salad
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 752   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 893   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     $8.99
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69

# %% [markdown]
# ### 33. df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 데이터 프레임화 한 후, item_name를 기준으로 중복행이 있으면 제거하되 첫번째 케이스만 남겨라

# %%
df_steak_bowl =  df[(df['item_name']=='Steak Salad') | (df['item_name'] == 'Bowl')]
df_steak_bowl.drop_duplicates('item_name')
# Out:
#      order_id  quantity    item_name  \
# 445       193         3         Bowl
# 664       276         1  Steak Salad
#
#                                     choice_description item_price
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 664  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99

# %% [markdown]
# ### 34. df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 데이터 프레임화 한 후, item_name를 기준으로 중복행이 있으면 제거하되 마지막 케이스만 남겨라

# %%
df_steak_bowl =  df[(df['item_name']=='Steak Salad') | (df['item_name'] == 'Bowl')]
df_steak_bowl.drop_duplicates('item_name', keep='last')
# Out:
#       order_id  quantity    item_name  \
# 673        279         1         Bowl
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69

# %% [markdown]
# ### 35. df의 데이터 중 new_price값이 new_price값의 평균값 이상을 가지는 데이터들을 인덱싱하라.

# %%
df_raw[df_raw['new_price'].mean() <= df_raw['new_price']]
# Out:
#       quantity item_price  new_price
# 4            2    $16.98       16.98
# 5            1    $10.98       10.98
# 7            1    $11.75       11.75
# 8            1     $9.25        9.25
# 9            1     $9.25        9.25
# ...        ...        ...        ...
# 4617         1    $11.75       11.75
# 4618         1    $11.75       11.75
# 4619         1    $11.25       11.25
# 4620         1     $8.75        8.75
# 4621         1     $8.75        8.75
#
# [2890 rows x 3 columns]

# %% [markdown]
# ### 36. df의 데이터 중 item_name의 값이 Izze 데이터를 Fizzy Lizzy로 수정하라

# %%
df.loc[df.item_name == 'Izze', 'item_name'] = 'Fizzy Lizzy'

df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                            Fizzy Lizzy
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# `df[df['item_name']=='Izze'].item_name = 'Fizzy Lizzy'`
# 해당 코드는 원본 코드를 건드리지 못하므로, 단순히 복사만 가능함.
# 따라서 따로 loc를 써서 슬라이싱을 해줘야 함.

# %% [markdown]
# ### 37. df의 데이터 중 choice_description 값이 NaN 인 데이터의 갯수를 구하여라

# %%
df['choice_description'].isna().sum()
# Out:
# 1246

# %% [markdown]
# ### 38. df의 데이터 중 choice_description 값이 NaN 인 데이터를 NoData 값으로 대체하라(loc 이용)

# %%
df.loc[df.choice_description.isnull() == True, 'choice_description'] = 'NoData'
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                            Fizzy Lizzy
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                NoData     $2.39
# ...

# %% [markdown]
# ### 39. df의 데이터 중 choice_description 값에 Black이 들어가는 경우를 인덱싱하라.

# %%
df[df.choice_description.str.contains('Black')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 7            4         1         Steak Burrito
# 9            5         1         Steak Burrito
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4608      1829         1        Veggie Burrito
# 4611      1830         1        Veggie Burrito
# 4612      1831         1         Carnitas Bowl
# 4617      1833         1         Steak Burrito
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# ...

# %% [markdown]
# ### 40. df의 데이터 중 choice_description 값에 Vegetables 들어가지 않는 경우의 갯수를 출력하라

# %%
df[df.choice_description.str.contains('Vegetables')==False]['choice_description'].count()
# Out:
# 3900
