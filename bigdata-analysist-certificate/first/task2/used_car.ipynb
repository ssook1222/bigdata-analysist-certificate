# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/bigdata-analysist-certificate/blob/master/bigdata-analysist-certificate/first/task2/used_car.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 중고차 가격 예측 데이터

# %% [markdown]
# ### 패키지 다 불러오기

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ### 데이터 불러오기

# %%
x_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/X_train.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/y_train.csv')
x_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/X_test.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/carsprice/y_test.csv')

# %% [markdown]
# ### 데이터 전처리

# %%
display(x_train)
# Out:
#       carID     brand      model  year transmission  mileage fuelType    tax  \
# 0     13207    hyundi   Santa Fe  2019    Semi-Auto     4223   Diesel  145.0
# 1     17314  vauxhall        GTC  2015       Manual    47870   Diesel  125.0
# 2     12342      audi        RS4  2019    Automatic     5151   Petrol  145.0
# 3     13426        vw   Scirocco  2016    Automatic    20423   Diesel   30.0
# 4     16004     skoda      Scala  2020    Semi-Auto     3569   Petrol  145.0
# ...     ...       ...        ...   ...          ...      ...      ...    ...
# 4955  16898      merc   GL Class  2015    Automatic    24314   Diesel  125.0
# 4956  14416       bmw   6 Series  2017    Automatic    18000   Diesel  145.0
# 4957  15453        vw         CC  2015       Manual    84932   Diesel   30.0
# 4958  14666      audi         A7  2017    Semi-Auto    30150   Diesel  145.0
# 4959  15135      merc        SLK  2014    Automatic    40230   Diesel  150.0
#
#        mpg  engineSize
# ...

# %% [markdown]
# #### 결측치 확인

# %%
print(x_train.isna().sum())
# Out:
# carID           0
# brand           0
# model           0
# year            0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# 없으므로 그냥 진행

# %% [markdown]
# #### 라벨 인코딩

# %%
print(x_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   carID         4960 non-null   int64
#  1   brand         4960 non-null   object
#  2   model         4960 non-null   object
#  3   year          4960 non-null   int64
#  4   transmission  4960 non-null   object
#  5   mileage       4960 non-null   int64
#  6   fuelType      4960 non-null   object
#  7   tax           4960 non-null   float64
#  8   mpg           4960 non-null   float64
#  9   engineSize    4960 non-null   float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 387.6+ KB
# None

# %%
le = LabelEncoder()
columns = ['brand', 'model', 'transmission', 'fuelType']

for column in columns:
  x_train[column] = le.fit_transform(x_train[column])
  x_test[column] = le.fit_transform(x_test[column])

# %% [markdown]
# ### 데이터 모델링하기

# %%
dtr = DecisionTreeRegressor()
model = dtr.fit(x_train, y_train)
predicts = model.predict(x_test)
print(mean_absolute_error(predicts[:,1], y_test['price']))
# Out:
# 3230.383982035928

# %% [markdown]
# ### 제출하기

# %%
result = pd.DataFrame(columns = y_train.columns, data = predicts)

# %%
display(result.head(5))
result.to_csv('answer.csv')
# Out:
#      carID    price
# 0  13092.0  38000.0
# 1  14002.0  22795.0
# 2  14293.0  54990.0
# 3  12084.0  15490.0
# 4  12559.0  47992.0
