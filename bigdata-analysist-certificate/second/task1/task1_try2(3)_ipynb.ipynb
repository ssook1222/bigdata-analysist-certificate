# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/bigdata-analysist-certificate/blob/master/bigdata-analysist-certificate/second/task1/task1_try2(3)_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 월드컵 출전선수 골기록 데이터

# %%
import pandas as pd

df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/worldcup/worldcupgoals.csv')
df.head()
# Out:
#            Player  Goals                Years  Country
# 0  Miroslav Klose     16  2002-2006-2010-2014  Germany
# 1         Ronaldo     15       1998-2002-2006   Brazil
# 2     Gerd Muller     14            1970-1974  Germany
# 3   Just Fontaine     13                 1958   France
# 4            Pele     12  1958-1962-1966-1970   Brazil

# %% [markdown]
# ### Question 21
#
# 주어진 전체 기간의 각 나라별 골득점수 상위 5개 국가와 그 득점수를 데이터프레임형태로 출력하라

# %%
pd.DataFrame(df[['Goals', 'Country']].groupby('Country', as_index = False ).sum()).sort_values('Goals', ascending = False).reset_index(drop = True).head(5)
# Out:
#      Country  Goals
# 0     Brazil    228
# 1    Germany    226
# 2  Argentina    135
# 3      Italy    123
# 4     France    115

# %% [markdown]
# ### Question 22
#
# 주어진 전체기간동안 골득점을 한 선수가 가장 많은 나라 상위 5개 국가와 그 선수 숫자를 데이터 프레임 형식으로 출력하라

# %%
df22 = df[['Goals', 'Country', 'Player']].groupby(['Player', 'Country'], as_index = False).sum()

# %%
df22[['Player',	'Country']].groupby('Country', as_index = False).count().sort_values('Player', ascending = False).reset_index(drop = True).head(5)
# Out:
#      Country  Player
# 0     Brazil      80
# 1    Germany      78
# 2      Italy      60
# 3  Argentina      59
# 4     France      58

# %% [markdown]
# ### Question 23
#
# Years 컬럼은 년도 -년도 형식으로 구성되어있고, 각 년도는 4자리 숫자이다. 년도 표기가 4자리 숫자로 안된 케이스가 존재한다. 해당 건은 몇건인지 출력하라

# %%
cnt = 0

# %%
def chk(x):
  global cnt
  x_list = list(x.split('-'))
  for x_raw in x_list:
    if len(x_raw) != 4:
      cnt += 1

# %%
df.Years.apply(chk)
print(cnt)
# Out:
# 45

# %% [markdown]
# ### Question 24
#
# **Q3에서 발생한 예외 케이스를 제외한 데이터프레임을 df2라고 정의하고 데이터의 행의 숫자를 출력하라 (아래 문제부터는 df2로 풀이하겠습니다) **

# %%
def chk2(x):
  x_list = list(x.split('-'))
  for x_raw in x_list:
    if len(x_raw) != 4:
      return False
  return True

# %%
df['make2'] = df.Years.apply(chk2)
df2 = df[(df.make2 == True)]

# %%
print(df2.shape[0])
# Out:
# 1250

# %% [markdown]
# ### Question 25
#
# 월드컵 출전횟수를 나타내는 ‘LenCup’ 컬럼을 추가하고 4회 출전한 선수의 숫자를 구하여라

# %%
all_check = 0

# %%
def chk2(x):
  global all_check
  cnt = 0

  x_list = list(x.split('-'))
  if len(x_list) == 4:
    all_check += 1
    cnt += len(x_list)
  else:
    cnt += len(x_list)
  return cnt

# %%
df2['LenCup'] = df2.Years.apply(chk2)
# Out:
# <ipython-input-65-21bbea575d95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['LenCup'] = df2.Years.apply(chk2)

# %%
display(df2)
print(all_check)
# Out:
#                    Player  Goals                Years     Country  make2  \
# 0          Miroslav Klose     16  2002-2006-2010-2014     Germany   True
# 1                 Ronaldo     15       1998-2002-2006      Brazil   True
# 2             Gerd Muller     14            1970-1974     Germany   True
# 3           Just Fontaine     13                 1958      France   True
# 4                    Pele     12  1958-1962-1966-1970      Brazil   True
# ...                   ...    ...                  ...         ...    ...
# 1290        Josip Skoblar      1                 1962  Yugoslavia   True
# 1291          Safet Susic      1            1982-1990  Yugoslavia   True
# 1292  Aleksandar Tirnanic      1                 1930  Yugoslavia   True
# 1293  Djordje Vujadinovic      1                 1930  Yugoslavia   True
# 1294         Branko Zebec      1            1954-1958  Yugoslavia   True
#
#       LenCup
# 0          4
# 1          3
# 2          2
# 3          1
# 4          4
# ...

# %% [markdown]
# ### Question 26
#
# Yugoslavia 국가의 월드컵 출전횟수가 2회인 선수들의 숫자를 구하여라

# %%
print(df2[(df2.Country == 'Yugoslavia') & (df2.LenCup ==2)].Player.count())
# Out:
# 7

# %% [markdown]
# ### Question 27
#
# 2002년도에 출전한 전체 선수는 몇명인가?

# %%
chk27 = 0

# %%
def chk3(x):
  global chk27
  if '2002' in x:
    chk27 += 1

# %%
df2.Years.apply(chk3)
print(chk27)
# Out:
# 156

# %% [markdown]
# ### Question 28
#
# 이름에 ‘carlos’ 단어가 들어가는 선수의 숫자는 몇 명인가? (대, 소문자 구분 x)

# %%
chk28 = 0

def chk4(x):
  global chk28
  if 'carlos' in x.lower():
    chk28 += 1

df2.Player.apply(chk4)
print(chk28)
# Out:
# 13

# %% [markdown]
# ### Question 29
#
# 월드컵 출전 횟수가 1회뿐인 선수들 중에서 가장 많은 득점을 올렸던 선수는 누구인가?

# %%
print(df2[(df2.LenCup ==1)].sort_values('Goals', ascending = False).head(1).Player.values[0])
# Out:
# Just Fontaine

# %% [markdown]
# ### Question 30
#
# 월드컵 출전횟수가 1회 뿐인 선수들이 가장 많은 국가는 어디인가?

# %%
df30 = df2[(df2.LenCup ==1)]

# %%
print(df30.groupby('Country', as_index = False).count().sort_values('Player', ascending = False).head(1).Country.values[0])
# Out:
# Brazil
