# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/bigdata-analysist-certificate/blob/master/bigdata-analysist-certificate/second/task1/task1_try2(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 서울시 따릉이 이용정보 데이터

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bicycle/seoul_bi.csv')

# %% [markdown]
# ### Question 31
#
# 대여일자별 데이터의 수를 데이터프레임으로 출력하고, 가장 많은 데이터가 있는 날짜를 출력하라

# %%
import datetime as dt

# %%
df['대여일자'] = pd.to_datetime(df.대여일자)

# %%
display(df.groupby('대여일자', as_index = False).count().sort_values('이용건수', ascending = False)[['대여일자', '이용건수']])
print(df.groupby('대여일자', as_index = False).count().sort_values('이용건수', ascending = False).head(1).대여일자.values[0])
# Out:
#          대여일자   이용건수
# 3  2021-06-04  56788
# 1  2021-06-02  56100
# 7  2021-06-08  55623
# 13 2021-06-14  54945
# 8  2021-06-09  54507
# 4  2021-06-05  52730
# 6  2021-06-07  52623
# 10 2021-06-11  52089
# 11 2021-06-12  48569
# 0  2021-06-01  48081
# 5  2021-06-06  47787
# 12 2021-06-13  43131
# 9  2021-06-10  36992
# 2  2021-06-03  18985
# 2021-06-04T00:00:00.000000000

# %% [markdown]
# ### Question 32
#
# 각 일자의 요일을 표기하고 (‘Monday’ ~’Sunday’) ‘day_name’컬럼을 추가하고 이를 이용하여 각 요일별 이용 횟수의 총합을 데이터 프레임으로 출력하라

# %%
df['day_name'] = df.대여일자.dt.day_name()

# %%
df.value_counts('day_name')
# Out:
# day_name
# Wednesday    110607
# Friday       108877
# Monday       107568
# Tuesday      103704
# Saturday     101299
# Sunday        90918
# Thursday      55977
# dtype: int64

# %% [markdown]
# ### Question 33
#
# 각 요일별 가장 많이 이용한 대여소의 이용횟수와 대여소 번호를 데이터 프레임으로 출력하라

# %%
df.groupby(['day_name', '대여소번호'], as_index = False).size().sort_values('size', ascending = False).drop_duplicates('day_name', keep = 'first')
# Out:
#         day_name  대여소번호  size
# 5191    Saturday    502   378
# 7611      Sunday    502   372
# 14820  Wednesday    502   282
# 348       Friday    502   277
# 12421    Tuesday    502   267
# 2769      Monday    502   242
# 11482   Thursday   2715   137

# %% [markdown]
# ### Question 34
#
# 나이대별 대여구분 코드의 (일일권/전체횟수) 비율을 구한 후 가장 높은 비율을 가지는 나이대를 확인하라. 일일권의 경우 일일권 과 일일권(비회원)을 모두 포함하라

# %%
df
# Out:
#              대여일자  대여시간  대여소번호 대여구분코드 성별 연령대코드  이용건수     운동량   탄소량     이동거리  \
# 0      2021-06-01     0   3541    정기권  F  ~10대     1    0.00  0.00     0.00
# 1      2021-06-01     0    765    정기권  F  ~10대     1   27.21  0.35  1526.81
# 2      2021-06-01     0   2637    정기권  F  ~10대     1   41.40  0.37  1608.56
# 3      2021-06-01     0   2919    정기권  F  ~10대     1    0.00  0.00     0.00
# 4      2021-06-01     0    549    정기권  F  ~10대     1   13.04  0.17   731.55
# ...           ...   ...    ...    ... ..   ...   ...     ...   ...      ...
# 678945 2021-06-14    23   4623    정기권  M   60대     1   32.92  0.30  1279.01
# 678946 2021-06-14    23   2331    정기권  M   60대     1   11.88  0.09   400.00
# 678947 2021-06-14    23    722    정기권  M   60대     1   53.28  0.48  2070.00
# 678948 2021-06-14    23   3787    정기권  M  70대~     1  121.25  1.18  5103.30
# 678949 2021-06-14    23   1911    정기권  M  70대~     1   42.18  0.38  1638.70
#
#         사용시간 day_name
# 0          8  Tuesday
# ...

# %%
daily = df[(df.대여구분코드 == '일일권') | (df.대여구분코드 == '일일권(비회원)')].groupby('연령대코드', as_index = False).size()

# %%
total = df.groupby('연령대코드', as_index = False).size()

# %%
display(daily)
display(total)
# Out:
#   연령대코드   size
# 0   20대  59393
# 1   30대  31127
# 2   40대  12695
# 3   50대   4607
# 4   60대    819
# 5  70대~    158
# 6  ~10대  11540
#   연령대코드    size
# 0   20대  247561
# 1   30대  186722
# 2   40대  114799
# 3   50대   70428
# 4   60대   19288
# 5  70대~    3227
# 6  ~10대   36925

# %%
total['rate'] = daily['size'] / total['size']

# %%
print(total.sort_values('rate', ascending = False).head(1).연령대코드.values[0])
# Out:
# ~10대

# %% [markdown]
# ### Question 35
#
# 연령대별 평균 이동거리를 구하여라

# %%
print(df.groupby('연령대코드', as_index = False).mean()[['연령대코드', '이동거리']])
# Out:
#   연령대코드         이동거리
# 0   20대  3211.890552
# 1   30대  3341.443859
# 2   40대  3514.857416
# 3   50대  3593.668100
# 4   60대  3538.145737
# 5  70대~  3085.039641
# 6  ~10대  2634.426279
# <ipython-input-80-73e8ad274e9a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby('연령대코드', as_index = False).mean()[['연령대코드', '이동거리']])

# %% [markdown]
# ### Question 36
#
# 연령대 코드가 20대인 데이터를 추출하고,이동거리값이 추출한 데이터의 이동거리값의 평균 이상인 데이터를 추출한다.최종 추출된 데이터를 대여일자, 대여소 번호 순서로 내림차순 정렬 후 1행부터 200행까지의 탄소량의 평균을 소숫점 3째 자리까지 구하여라

# %%
df36 = df[((df.연령대코드 == '20대'))]

# %%
df36 = df36[(df36.이동거리 >= df36.이동거리.mean())]

# %%
df36.탄소량 = df36.탄소량.astype('float')
# Out:
# <ipython-input-109-270ee791b3ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df36.탄소량 = df36.탄소량.astype('float')

# %%
print(round(df36.sort_values(['대여일자','대여소번호'], ascending = False)[1:200].mean().탄소량, 3))
# Out:
# 1.611
# <ipython-input-111-67824d3cb54f>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   print(round(df36.sort_values(['대여일자','대여소번호'], ascending = False)[1:200].mean().탄소량, 3))
# <ipython-input-111-67824d3cb54f>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(round(df36.sort_values(['대여일자','대여소번호'], ascending = False)[1:200].mean().탄소량, 3))

# %% [markdown]
# ### Question 37
#
# 6월 7일 ~10대의 “이용건수”의 중앙값은?

# %%
print(df[((df.연령대코드 == '~10대') & (df.대여일자 == pd.to_datetime('2021-06-07')))].이용건수.median())
# Out:
# 1.0

# %% [markdown]
# ### Question 38
#
# 평일 (월~금) 출근 시간대(오전 6,7,8시)의 대여소별 이용 횟수를 구해서 데이터 프레임 형태로 표현한 후 각 대여시간별 이용 횟수의 상위 3개 대여소와 이용횟수를 출력하라

# %%
df38 = df[(df.대여일자.dt.weekday == 1)]

# %%
df38 = df38[(df['대여시간'].isin([6,7,8]))].groupby(['대여시간', '대여소번호'], as_index = False).size()
# Out:
# <ipython-input-143-8a96bef87ab4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df38 = df38[(df['대여시간'].isin([6,7,8]))].groupby(['대여시간', '대여소번호'], as_index = False).size()

# %%
ans = df38.sort_values(['대여시간','size'],ascending=False).groupby('대여시간').head(3)
display(ans)
# Out:
#       대여시간  대여소번호  size
# 2869     8    646    22
# 3908     8   2701    21
# 2605     8    247    20
# 1045     7    259    18
# 1937     7   2107    15
# 1017     7    230    13
# 37       6    185     8
# 302      6   1028     8
# 747      6   2744     8

# %% [markdown]
# ### Question 39
#
# 이동거리의 평균 이상의 이동거리 값을 가지는 데이터를 추출하여 추출데이터의 이동거리의 표본표준편차 값을 구하여라

# %%
print(df[(df.이동거리.mean() <= df.이동거리)].이동거리.std())
# Out:
# 5092.139707505356

# %% [markdown]
# ### Question 40
#
# 남성(‘M’ or ‘m’)과 여성(‘F’ or ‘f’)의 이동거리값의 평균값을 구하여라

# %%
male = df[((df.성별 == 'M') | (df.성별 == 'M'))].이동거리.mean()
female = df[((df.성별 == 'F') | (df.성별 == 'f'))].이동거리.mean()

# %%
pd.DataFrame(columns = ['남자', '여자'], data = [{male, female}])
# Out:
#             남자           여자
# 0  3209.392786  3468.575025
