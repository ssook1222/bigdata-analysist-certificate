# %% [markdown]
# <a href="https://colab.research.google.com/github/ssook1222/bigdata-analysist-certificate/blob/master/bigdata-analysist-certificate/task1/task1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/happy2/happiness.csv',encoding='utf-8')
df.head()
# Out:
#    행복랭킹          나라명     점수  상대GDP  사회적지원  행복기대치  선택의 자유도    관대함  부패에 대한인식  \
# 0     1      Finland  7.769  1.340  1.587  0.986    0.596  0.153     0.393
# 1     2      Denmark  7.600  1.383  1.573  0.996    0.592  0.252     0.410
# 2     3       Norway  7.554  1.488  1.582  1.028    0.603  0.271     0.341
# 3     4      Iceland  7.494  1.380  1.624  1.026    0.591  0.354     0.118
# 4     5  Netherlands  7.488  1.396  1.522  0.999    0.557  0.322     0.298
#
#      년도
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %% [markdown]
# ## 전세계 행복도 지표 데이터

# %% [markdown]
# ### Question 41
#
# 데이터는 2018년도와 2019년도의 전세계 행복 지수를 표현한다. 각년도의 행복랭킹 10위를 차지한 나라의 행복점수의 평균을 구하여라

# %%
yr2019 = df[df.년도==2019].sort_values('점수', ascending = False).head(10).점수.values[9]
yr2018 = df[df.년도==2018].sort_values('점수', ascending = False).head(10).점수.values[9]

print( (yr2018 + yr2019) / 2 )
# Out:
# 7.259

# %% [markdown]
# ### Question 42
#
# 데이터는 2018년도와 2019년도의 전세계 행복 지수를 표현한다. 각년도의 행복랭킹 50위이내의 나라들의 각각의 행복점수 평균을 데이터프레임으로 표시하라

# %%
df_2019 = df[df.년도==2019].sort_values('점수', ascending = False).head(50).점수.mean()
df_2018 = df[df.년도==2018].sort_values('점수', ascending = False).head(50).점수.mean()

raw = pd.DataFrame({'년도' : [2018, 2019], '평균': [df_2018, df_2019]}).set_index('년도', drop = True, inplace = False)
raw
# Out:
#            평균
# 년도
# 2018  6.64678
# 2019  6.67002

# %% [markdown]
# ### Question 43
#
# 2018년도 데이터들만 추출하여 행복점수와 부패에 대한 인식에 대한 상관계수를 구하여라

# %%
df_43 = df[df.년도==2018]
df_43[['점수', '부패에 대한인식']].corr().iloc[0,1]
# Out:
# 0.40529152271510027

# %% [markdown]
# ### Question 44
#
# 2018년도와 2019년도의 행복랭킹이 변화하지 않은 나라명의 수를 구하여라

# %%
len(df[['행복랭킹','나라명']]) - len(df[['행복랭킹','나라명']].drop_duplicates())
# Out:
# 15

# %% [markdown]
# 중복 제거를 통해 행복랭킹이 변화하지 않은 나라의 수를 구할 수 있음.

# %% [markdown]
# ### Question 45
#
# 2019년도 데이터들만 추출하여 각변수간 상관계수를 구하고 내림차순으로 정렬한 후 상위 5개를 데이터 프레임으로 출력하라. 컬럼명은 v1,v2,corr으로 표시하라

# %%
df_corr = df[df.년도 ==2019].corr().unstack().to_frame().reset_index().dropna() # unstack과 to_frame을 사용해서 두 변수 사이의 상관관계를 구함.
df_corr = df_corr[df_corr[0] != 1].sort_values(0, ascending = False).drop_duplicates(0).head(5).reset_index(drop = True)
df_corr.columns = ['v1', 'v2', 'corr']
df_corr
# Out:
# <ipython-input-7-d12474bcd52a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df[df.년도 ==2019].corr().unstack().to_frame().reset_index().dropna() # unstack과 to_frame을 사용해서 두 변수 사이의 상관관계를 구함.
#       v1     v2      corr
# 0  행복기대치  상대GDP  0.835462
# 1  상대GDP     점수  0.793883
# 2  행복기대치     점수  0.779883
# 3  사회적지원     점수  0.777058
# 4  사회적지원  상대GDP  0.754906

# %% [markdown]
# `데이터프레임.columns = [컬럼 리스트]`를 통해 데이터프레임의 컬럼을 세팅할 수 있음.

# %% [markdown]
# ### Question 46
#
# 각 년도별 하위 행복점수의 하위 5개 국가의 평균 행복점수를 구하여라

# %%
df.groupby('년도').tail(5).groupby('년도').mean()[['점수']]
# Out:
# <ipython-input-23-cde7ffb0d2fe>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('년도').tail(5).groupby('년도').mean()[['점수']]
#           점수
# 년도
# 2018  3.1800
# 2019  3.1408

# %% [markdown]
# ### Question 47
#
# 2019년 데이터를 추출하고 해당데이터의 상대 GDP 평균 이상의 나라들과 평균 이하의 나라들의 행복점수 평균을 각각 구하고 그 차이값을 출력하라

# %%
df_2019 = df[df['년도'] == 2019]
df_2019[df_2019.상대GDP.mean() <= df_2019.상대GDP].점수.mean() - df_2019[df_2019.상대GDP.mean() >= df_2019.상대GDP].점수.mean()
# Out:
# 1.390483957219251

# %% [markdown]
# ### Question 48
#
# 각년도의 부패에 대한인식을 내림차순 정렬했을때 상위 20개 국가의 부패에 대한인식의 평균을 구하여라

# %%
df.sort_values(['년도', '부패에 대한인식'], ascending = False).groupby('년도').head(20).groupby(['년도']).mean()[['부패에 대한인식']]
# Out:
# <ipython-input-43-de37cc2007ba>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.sort_values(['년도', '부패에 대한인식'], ascending = False).groupby('년도').head(20).groupby(['년도']).mean()[['부패에 대한인식']]
#       부패에 대한인식
# 년도
# 2018    0.3267
# 2019    0.3201

# %% [markdown]
# ### Question 49
#
# 2018년도 행복랭킹 50위 이내에 포함됐다가 2019년 50위 밖으로 밀려난 국가의 숫자를 구하여라

# %%
res = set(df[(df.년도 == 2018) & (df.행복랭킹 <= 50)].나라명)-set(df[(df.년도 == 2019) & (df.행복랭킹 >= 50)].나라명)
len(res)
# Out:
# 46

# %% [markdown]
# ### Question 50
#
# 2018년, 2019년 모두 기록이 있는 나라들 중 년도별 행복점수가 가장 증가한 나라와 그 증가 수치는?

# %% [markdown]
# 다시 한 번 풀어보기!

# %%
count = df.나라명.value_counts()
target = count[count>=2].index

df2 =df.copy()

multiple = df2[df2.나라명.isin(target)].reset_index(drop=True)
multiple.loc[multiple['년도']==2018,'점수'] = multiple[multiple.년도 ==2018]['점수'].values * (-1)

result = multiple.groupby('나라명').sum()['점수'].sort_values().to_frame().iloc[-1]
result
# Out:
# 점수    0.87
# Name: Burundi, dtype: float64
